# %%
# Importing source scrpit
from FunctSource import*

# %%
Analize_data_file('Coll_5mm_depth_15mm.dat',5,15)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 91.44736842105263

# %%
Analize_data_file('Coll_5mm_depth_100mm.dat',5,100)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 81.57894736842105

# %%
Analize_data_file('Coll_5mm_depth_300mm.dat',5,300)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 80.26315789473685

# %%
Analize_data_file('Coll_50mm_depth_15mm.dat',50,15)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 50.0

# %%
Analize_data_file('Coll_50mm_depth_100mm.dat',50,100)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 40.131578947368425

# %%
Analize_data_file('Coll_50mm_depth_300mm.dat',50,300)
Ploting_results(norm=False)
# Out:
# Gamma analysis completed, GPR = 29.605263157894733

# %%
Analize_data_file('Coll_50mm_depth_15mmB.dat',50,15)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 53.289473684210535

# %%
Analize_data_file('Coll_50mm_depth_100mmB.dat',50,100)
Ploting_results()
# Out:
# Gamma analysis completed, GPR = 47.368421052631575

# %%
Analize_data_file('Coll_50mm_depth_300mmB.dat',50,300)
Ploting_results(norm=False)
# Out:
# Gamma analysis completed, GPR = 47.368421052631575
